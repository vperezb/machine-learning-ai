# %%
from tensorflow import keras
import cv2
import matplotlib.pyplot as plt

model = keras.models.load_model('dog_is_1.h5')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0624 18:20:43.726338 16072 deprecation.py:506] From C:\Users\Orwell\Documents\GitProjects\machine-learning-ai\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0624 18:20:43.727365 16072 deprecation.py:506] From C:\Users\Orwell\Documents\GitProjects\machine-learning-ai\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0624 18:20:43.728333 16072 deprecation.py:506] From C:\Users\Orwell\Documents\GitProjects\machine-learning-ai\venv\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0624 18:20:44.114152 16072 deprecation.py:323] From C:\Users\Orwell\Documents\GitProjects\machine-learning-ai\venv\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
img_array = cv2.imread(r'C:\Users\Orwell\Downloads\cat_1.jpg',cv2.IMREAD_GRAYSCALE)
new_img_array = cv2.resize(img_array, dsize=(80, 80))
plt.imshow(new_img_array,cmap="gray")

# %%
int(round(model.predict(new_img_array.reshape(-1,80,80,1)/255)[0][0]))
# Out:
# 0
